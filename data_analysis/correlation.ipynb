# %%
import os
import warnings
import pandas as pd

import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

col_names =  ["Locality",     
              "Type_of_property",
              "Subtype_of_property",
              "Price",
              "Type_of_sale",
              "Number_of_rooms",
              "Living_Area",
              "Fully_equipped_kitchen",
              "Furnished",
              "Open_fire",
              "Terrace",
              "Terrace_Area",
              "Garden",
              "Garden_Area",
              "Surface_area_of_the_plot_of_land",
              "Number_of_facades",
              "Swimming_pool",
              "State_of_the_building"
              ]

file_path = r"C:\Users\Sacha\Documents\BeCode\real-estate-price-prediction\data_analysis\main_csv.csv" 
df_final = pd.read_csv(file_path)

# %% [markdown]
# correlation between numeric datas

# %%
# drop the collumn locality, must not be considerred as a number
df_corr = df_final.drop(df_final.columns[0],axis=1)
#drop collumn open fire
df_corr = df_final.drop(df_final.columns[9],axis=1)


# Plot the correlation matrix using a heatmap
corr = df_corr.corr(numeric_only=True)
#-----------symetric
#sns.heatmap(corr, annot=True, cmap='coolwarm')
#-----------only down part
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, mask=mask,annot=True, cmap='coolwarm')

plt.show()
