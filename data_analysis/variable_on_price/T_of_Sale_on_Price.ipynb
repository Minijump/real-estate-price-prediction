# %% [markdown]
# # effect of tthe type of sale on the price

# %%
import os
import warnings
import pandas as pd

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
import seaborn.objects as so
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
col_names =  ["Locality",     
              "Type_of_property",
              "Subtype_of_property",
              "Price",
              "Type_of_sale",
              "Number_of_rooms",
              "Living_Area",
              "Fully_equipped_kitchen",
              "Furnished",
              "Open_fire",
              "Terrace",
              "Terrace_Area",
              "Garden",
              "Garden_Area",
              "Surface_area_of_the_plot_of_land",
              "Number_of_facades",
              "Swimming_pool",
              "State_of_the_building"
              ]

file_path = r"C:\Users\Sacha\Documents\BeCode\real-estate-price-prediction\data_analysis\main_csv.csv" 
df_final = pd.read_csv(file_path)
#df_final = df_final.dropna(subset=['Type_of_sale'])

# %%
df_final["Type_of_sale"] = df_final["Type_of_sale"].fillna("NAN")

# %%
freq_type = df_final["Type_of_sale"].value_counts()
plt.pie(freq_type, labels=freq_type.index, autopct='%1.1f%%')
plt.title("distribution of the type of sales in the data")
plt.show()

# %%
prices_groupby_loc = df_final.groupby("Type_of_sale")["Price"]
median_prices = prices_groupby_loc.median().sort_values()
print(median_prices)
# Out:
# Type_of_sale
# annuity_without_lump_sum              1435.0
# annuity_monthly_amount               50000.0
# first_session_with_reserve_price    187750.0
# residential_sale                    329000.0
# Name: Price, dtype: float64

# %% [markdown]
# Annuity have to be deleted, dont know what is first_session_with_reserve_price, so I will keep only residential_sale
